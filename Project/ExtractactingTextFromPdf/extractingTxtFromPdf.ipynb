# %%
import PyPDF2

# %%
pdfFileObj = open('round.pdf','rb')

# %%
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
print(pdfReader.numPages)
numOfPages = pdfReader.numPages
# Out:
# 5

# %%
for i in range(0, numOfPages):
    print("Page Number: " + str(i))
    print("- - - - - - - - - - - - - - - - - - - -")
    pageObj = pdfReader.getPage(i)
    print(pageObj.extractText())
    print("- - - - - - - - - - - - - - - - - - - -")
    
pdfFileObj.close()
# Out:
# Page Number: 0
# - - - - - - - - - - - - - - - - - - - -
# D
# i
# rState Common Entrance Test Cell
# Cut Off List for Maharashtra & Minority Seats of CAP Round - II for Admission to First Year of Four Year Full Time Degree Courses in
# Engineering and Technology for the Academic Year 2020-21Government of Maharashtra
# 1002 - Government College of Engineering, Amravati
# 100219110 - Civil Engineering
# Status: Government Autonomous
# State Level
# GOPENS GSCS GSTS GNT1S GNT2S GOBCS LOPENS LNT2S LOBCS PWDOPENS ORPHAN EWS TFWS
#   I 15776
# (89.1295044)17165
# (88.1835221)49645
# (61.5008019)21718
# (84.9867329)30453
# (78.6913723)16685
# (88.4669272)9318
# (93.5175192)28439
# (80.1092735)16120
# (88.8762122)22669
# (84.3283582)14004
# (90.3542062)
#   I-Non
# PWD16031
# (88.9911299)
#   VII 16757
# (88.4060389)Stage
# 100224210 - Computer Science and Engineering
# Status: Government Autonomous
# State Level
# GOPENS GSTS GOBCS LOPENS DEFOPENS ORPHAN EWS TFWS
#   I 4250
# (96.9865789)28428
# (80.1315568)4935
# (96.5053763)3990
# (97.1204962)12303
# (91.4493121)6175
# (95.6613489)2973
# (97.8369823)
#   VII 4380
# (96.8684055)Stage
# 100224610 - Information Technology
# Status: Government Autonomous
# State Level
# GOPENS GSCS GSTS GOBCS LOPENS LNT3S LOBCS PWDOPENS ORPHAN EWS TFWS
#   I 6699
# (95.2607052)13265
# (90.8751696)39961
# (70.8036549)6957
# (95.0924207)5135
# (96.3685996)30316
# (78.7873849)5156
# (96.3524828)8331
# (94.1655360)6390
# (95.5178877)
#   I-Non
# PWD6882
# (95.1795093)
#   VII 6887
# (95.1795093)Stage
# 100229310 - Electrical Engineering
# Status: Government Autonomous
# State Level
# GOPENS GSCS GSTS GVJS GNT3S GOBCS LSCS LOBCS PWDOPENS DEFOPENS DEFROBCS ORPHAN EWS TFWS
#   I 14715
# (89.8624124)19080
# (86.8225057)40844
# (70.0898915)15689
# (89.1321551)24275
# (83.2244189)16817
# (88.3934219)21809
# (84.9497763)14088
# (90.2594711)53289
# (57.8190533)67209
# (40.1592803)16791
# (88.4023565)14485
# (90.0024869)
#   I-Non
# PWD14883
# (89.7454143)
#   VII 15509
# (89.3221913)Stage
# 1Legends: Start Character G-General, L-Ladies, End Character H-Home University, O-Other than Home University, S-State Level,
#  PWDR :  PWD Common Reserved Seat, DEFR :  Defense Common Reserved Seat.
# * Maharashtra State Seats - Cut Off Indicates State General Merit No .; Figures in bracket Indicates MHT- CET PCM Percentile
# - - - - - - - - - - - - - - - - - - - -
# Page Number: 1
# - - - - - - - - - - - - - - - - - - - -
# D
# i
# rState Common Entrance Test Cell
# Cut Off List for Maharashtra & Minority Seats of CAP Round - II for Admission to First Year of Four Year Full Time Degree Courses in
# Engineering and Technology for the Academic Year 2020-21Government of Maharashtra
# 1002 - Government College of Engineering, Amravati
# 100237210 - Electronics and Telecommunication Engg
# Status: Government Autonomous
# State Level
# GOPENS GSCS GSTS GNT1S GNT2S GOBCS LOPENS LSCS LOBCS PWDOPENS DEFOPENS ORPHAN EWS TFWS
#   I 9087
# (93.6748736)13812
# (90.4381610)47845
# (63.4007679)10529
# (92.6966758)17461
# (87.9631628)10401
# (92.7814674)10835
# (92.5014125)25261
# (82.3921928)13745
# (90.4789478)12424
# (91.3955929)12370
# (91.4432402)11732
# (91.8885038)
#   I-Non
# PWD9984
# (93.0502846)
#   VII 10613
# (92.6253687)Stage
# 100246610 - Instrumentation Engineering
# Status: Government Autonomous
# State Level
# GOPENS GSCS GSTS GNT3S GOBCS LOPENS LSTS LNT2S LOBCS PWDOPENS DEFOPENS EWS TFWS
#   I 22702
# (84.3283582)41839
# (69.4150658)82496
# (13.5830691)82691
# (13.4337001)24187
# (83.2711597)22518
# (84.4607557)24293
# (83.2244189)33755
# (76.0194676)23914
# (83.3816935)
#   I-Non
# Defence22261
# (84.6278795)
#   I-Non
# PWD24316
# (83.2189846)
#   VII 24228
# (83.2450493)23958
# (83.3518788)Stage
# 100261210 - Mechanical Engineering
# Status: Government Autonomous
# State Level
# GOPENS GSCS GSTS GNT2S GOBCS LOPENS LSCS LNT1S LNT3S LOBCS PWDOPENS ORPHAN EWS TFWS
#   I 12069
# (91.6459813)23045
# (84.0866925)40044
# (70.8036549)21108
# (85.4489429)15013
# (89.6179581)22122
# (84.7041731)30640
# (78.4473166)46577
# (64.9940968)22130
# (84.7041731)23742
# (83.4681792)12021
# (91.6795697)
#   II 44336
# (66.7530038)
#   I-Non
# PWD12052
# (91.6459813)
#   VII 15208
# (89.4945819)Stage
# 1Legends: Start Character G-General, L-Ladies, End Character H-Home University, O-Other than Home University, S-State Level,
#  PWDR :  PWD Common Reserved Seat, DEFR :  Defense Common Reserved Seat.
# * Maharashtra State Seats - Cut Off Indicates State General Merit No .; Figures in bracket Indicates MHT- CET PCM Percentile
# - - - - - - - - - - - - - - - - - - - -
# Page Number: 2
# - - - - - - - - - - - - - - - - - - - -
# D
# i
# rState Common Entrance Test Cell
# Cut Off List for Maharashtra & Minority Seats of CAP Round - II for Admission to First Year of Four Year Full Time Degree Courses in
# Engineering and Technology for the Academic Year 2020-21Government of Maharashtra
# 1005 - Sant Gadge Baba Amravati University,Amravati
# 100550310 - Food Technology
# Status: University Department
# Home University Seats Allotted to Home University Candidates
# GSCH GOBCH LSCH LOBCH PWDOPENH
#   I 61213
# (48.1429399)40902
# (69.9557928)79193
# (20.0386881)36588
# (73.6895417)
#   I-Non
# PWD37275
# (73.3069659)Stage
# Other Than Home University Seats Allotted to Other Than Home University Candidates
# GOPENO GSTO
#   I 20463
# (85.8338314)52564
# (58.7564176)Stage
# State Level
# DEFOPENS TFWS
#   I 23558
# (83.7275002)
#   I-Non
# Defence24224
# (83.2711597)Stage
# 1Legends: Start Character G-General, L-Ladies, End Character H-Home University, O-Other than Home University, S-State Level,
#  PWDR :  PWD Common Reserved Seat, DEFR :  Defense Common Reserved Seat.
# * Maharashtra State Seats - Cut Off Indicates State General Merit No .; Figures in bracket Indicates MHT- CET PCM Percentile
# - - - - - - - - - - - - - - - - - - - -
# Page Number: 3
# - - - - - - - - - - - - - - - - - - - -
# D
# i
# rState Common Entrance Test Cell
# Cut Off List for Maharashtra & Minority Seats of CAP Round - II for Admission to First Year of Four Year Full Time Degree Courses in
# Engineering and Technology for the Academic Year 2020-21Government of Maharashtra
# 1005 - Sant Gadge Baba Amravati University,Amravati
# 100551710 - Oil and Paints Technology
# Status: University Department
# Home University Seats Allotted to Home University Candidates
# GOPENH GSTH GVJH GNT3H LSCH PWDOPENH
#   I 47089
# (64.0931268)
#   II 81568
# (15.7020873)
#   I-Non
# PWD49794
# (61.4630190)
#   VII 81200
# (16.6127829)85387
# (7.9250601)80641
# (17.2098712)Stage
# Home University Seats Allotted to Other Than Home University Candidates
# LOPENH
#   I 41889
# (69.4150658)Stage
# Other Than Home University Seats Allotted to Other Than Home University Candidates
# GOPENO GNT3O
#   I 77842
# (22.4513080)
#   VII 81354
# (15.7493794)Stage
# State Level
# DEFOPENS EWS TFWS
#   I 64254
# (43.7615405)48425
# (62.8864315)
#   I-Non
# Defence56746
# (53.5074466)Stage
# 1Legends: Start Character G-General, L-Ladies, End Character H-Home University, O-Other than Home University, S-State Level,
#  PWDR :  PWD Common Reserved Seat, DEFR :  Defense Common Reserved Seat.
# * Maharashtra State Seats - Cut Off Indicates State General Merit No .; Figures in bracket Indicates MHT- CET PCM Percentile
# - - - - - - - - - - - - - - - - - - - -
# Page Number: 4
# - - - - - - - - - - - - - - - - - - - -
# D
# i
# rState Common Entrance Test Cell
# Cut Off List for Maharashtra & Minority Seats of CAP Round - II for Admission to First Year of Four Year Full Time Degree Courses in
# Engineering and Technology for the Academic Year 2020-21Government of Maharashtra
# 1005 - Sant Gadge Baba Amravati University,Amravati
# 100552410 - Paper and Pulp Technology
# Status: University Department
# Home University Seats Allotted to Other Than Home University Candidates
# GOPENH GNT2H
#   I 72318
# (32.0471506)82778
# (13.2928186)Stage
# Other Than Home University Seats Allotted to Other Than Home University Candidates
# GOBCO
#   I 83532
# (11.8793003)Stage
# State Level
# TFWS
#   I 52050
# (59.1576541)Stage
# 1Legends: Start Character G-General, L-Ladies, End Character H-Home University, O-Other than Home University, S-State Level,
#  PWDR :  PWD Common Reserved Seat, DEFR :  Defense Common Reserved Seat.
# * Maharashtra State Seats - Cut Off Indicates State General Merit No .; Figures in bracket Indicates MHT- CET PCM Percentile
# - - - - - - - - - - - - - - - - - - - -
